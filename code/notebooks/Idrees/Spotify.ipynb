# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
spotify = pd.read_excel('spotify_all.xlsx')

# %%
spotify
# Out:
#                                           name                   album  \
# 0                              Blinding Lights             After Hours
# 1                                        Venus                 At Home
# 2                             Streets Favorite    Queensbridge Project
# 3                               Bésame - Remix          Bésame (Remix)
# 4                       Mood (feat. iann dior)  Mood (feat. iann dior)
# ...                                        ...                     ...
# 6212                                   Hold On                 Hold On
# 6213  Lemon Pepper Freestyle (feat. Rick Ross)           Scary Hours 2
# 6214                                Faded Love              Faded Love
# 6215                             No Going Back                  Moodie
# 6216                              Life Letters            Life Letters
#
#                         artist release_date  length  popularity  acousticness  \
# ...

# %%
shazam = pd.read_csv('song_time_serie_top_200_belgium.csv',
                    parse_dates=['Date'], index_col=0)

# %%
shazam.head(10).T
# Out:
# Date                                            2020-11-14  \
# Top_1    ('Jaap Reesema & Pommelien Thijs', 'Nu Wij Nie...
# Top_2                ('Regi & Camille', 'Vergeet De Tijd')
# Top_3                       ('Dua Lipa & Angele', 'Fever')
# Top_4    ('Ofenbach & Quarterhead Feat. Norma Jean Mart...
# Top_5                 ('David Guetta & Sia', "Let's Love")
# ...                                                    ...
# Top_196                              ('Madcon', "Beggin'")
# Top_197      ('Dominica', 'Gotta Let You Go (Bicep Edit)')
# Top_198  ('Mr Eazi & Major Lazer Feat. Nicki Minaj & K4...
# Top_199                    ('Ween', 'Buenas Tardes Amigo')
# Top_200                           ('Maxim Lany', 'Closer')
#
# Date                                            2020-11-21  \
# Top_1    ('Jaap Reesema & Pommelien Thijs', 'Nu Wij Nie...
# Top_2                       ('Dua Lipa & Angele', 'Fever')
# Top_3                 ('David Guetta & Sia', "Let's Love")
# ...

# %%
Ultratop = pd.read_excel('songs/20-11-14.xlsx')

# %%
import os

# %%
files = os.listdir('songs/')

# %%
files
# Out:
# ['20-11-14.xlsx',
#  '20-11-21.xlsx',
#  '20-11-28.xlsx',
#  '20-12-05.xlsx',
#  '20-12-12.xlsx',
#  '20-12-19.xlsx',
#  '20-12-26.xlsx',
#  '21-01-02.xlsx',
#  '21-01-09.xlsx',
#  '21-01-16.xlsx',
#  '21-01-23.xlsx',
#  '21-01-30.xlsx',
#  '21-02-06.xlsx',
#  '21-02-13.xlsx',
#  '21-02-20.xlsx',
#  '21-02-27.xlsx',
#  '21-03-06.xlsx']

# %%
ultra_top = pd.DataFrame()
for file in files:
    data = pd.read_excel(f'songs/{file}')
    ultra_top = ultra_top.append(data)

# %%
ultra_top
# Out:
#      #                                      Artiste               Titre
# 0    1                       Dua Lipa feat. Angèle                Fever
# 1    2                    24kGoldn feat. Iann Dior                 Mood
# 2    3                       Joel Corry feat. MNEK         Head & Heart
# 3    4  Master KG feat. Burna Boy & Nomcebo Zikode   Jerusalema (Remix)
# 4    5                          David Guetta & Sia           Let's Love
# ..  ..                                          ...                 ...
# 45  46                       Joel Corry feat. MNEK         Head & Heart
# 46  47      Grand Corps Malade & Camille Lellouche       Mais je t'aime
# 47  48                                  The Weeknd      Blinding Lights
# 48  49                         Amel Bent x Imen Es        Jusqu'au bout
# 49  50                               Antoine Delie              Dis-moi
#
# [850 rows x 3 columns]

# %%
counting= []
for i in ultra_top.Artiste.values:
    if i not in counting:
        counting.append(i)

# %%
from collections import Counter
Counter(counting)
# Out:
# Counter({'Dua Lipa feat. Angèle\xa0': 1,
#          '24kGoldn feat. Iann Dior\xa0': 1,
#          'Joel Corry feat. MNEK\xa0': 1,
#          'Master KG feat. Burna Boy & Nomcebo Zikode\xa0': 1,
#          'David Guetta & Sia\xa0': 1,
#          'Amel Bent x Imen Es\xa0': 1,
#          'Vianney\xa0': 1,
#          'Zoe Wees\xa0': 1,
#          'Sch - Kofs - Jul - Naps - Soso Maness - Elams - Solda - Houari\xa0': 1,
#          'Lucky Luke\xa0': 1,
#          'Ava Max\xa0': 1,
#          'Miley Cyrus\xa0': 1,
#          'BTS\xa0': 1,
#          'Ariana Grande\xa0': 1,
#          'Kygo x Tina Turner\xa0': 1,
#          'Booba\xa0': 1,
#          'Jason Derulo\xa0': 1,
#          'Justin Bieber feat. Chance The Rapper\xa0': 1,
#          'Kendji Girac feat. Gims\xa0': 1,
#          'Vitaa & Slimane\xa0': 1,
#          'Clean Bandit and Mabel feat. 24kGoldn\xa0': 1,
#          'Naza feat. Niska\xa0': 1,
#          'Calogero\xa0': 1,
#          'Shawn Mendes\xa0': 1,
# ...

# %%
spotify['popularity'] = pd.qcut(spotify['popularity'], q=5, labels=[1,2,3,4,5])

# %%
spotify
# Out:
#                                           name                   album  \
# 0                              Blinding Lights             After Hours
# 1                                        Venus                 At Home
# 2                             Streets Favorite    Queensbridge Project
# 3                               Bésame - Remix          Bésame (Remix)
# 4                       Mood (feat. iann dior)  Mood (feat. iann dior)
# ...                                        ...                     ...
# 6212                                   Hold On                 Hold On
# 6213  Lemon Pepper Freestyle (feat. Rick Ross)           Scary Hours 2
# 6214                                Faded Love              Faded Love
# 6215                             No Going Back                  Moodie
# 6216                              Life Letters            Life Letters
#
#                         artist release_date  length popularity  acousticness  \
# ...

# %%
spotify['Shazam'] =
